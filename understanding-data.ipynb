# %%
# %pylab inline

import numpy as np
from resnet import tool
from resnet.model import ResNet
import tensorflow as tf
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.1, allow_growth=True)
sess = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %% [markdown]
# # Data

# %%
train_x, train_y, test_x, test_y = tool.load_data('_dataset')
print('train_x:', train_x.shape)
print('train_y:', train_y.shape)
print('test_x :', test_x.shape)
print('test_y :', test_y.shape)
# Out:
# train_x: (50000, 32, 32, 3)
# train_y: (50000,)
# test_x : (10000, 32, 32, 3)
# test_y : (10000,)

# %%
def random_images(x, y):
    N = x.shape[0]
    
    fig, plots = plt.subplots(5, 10)
    fig.set_figheight(8)
    fig.set_figwidth(14)
    plots = plots.reshape(-1)

    for i, p in enumerate(plots):
        samples = x[(y == i%10).reshape(-1)]
        idx = np.random.randint(samples.shape[0])
        p.imshow(samples[idx].astype('uint8'))
        
random_images(test_x, test_y)

# %% [markdown]
# # HDFS
